# %%
import os
import csv

# Animals
cat_images_path = 'Y:/Datasets/Test/Cats'
# Monster Cards
efct_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Effect_Monster_Cards'
fus_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Fusion_Monster_Cards'
link_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Link_Monster_Cards'
norm_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Normal_Monster_Cards'
pend_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Pendulum_Monster_Cards'
rit_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Ritual_Monster_Cards'
sync_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Synchro_Monster_Cards'
tok_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Token_Monster_Cards'
xyz_mon_path = 'Y:/Datasets/YuGiOhCards/Monster_Cards/Xyz_Monster_Cards'
# Spell Cards
cont_spell_path = 'Y:/Datasets/YuGiOhCards/Spell_Cards/Continuous_Spell_Cards'
equip_spell_path = 'Y:/Datasets/YuGiOhCards/Spell_Cards/Equip_Spell_Cards'
field_spell_path = 'Y:/Datasets/YuGiOhCards/Spell_Cards/Field_Spell_Cards'
norm_spell_path = 'Y:/Datasets/YuGiOhCards/Spell_Cards/Normal_Spell_Cards'
quick_spell_path = 'Y:/Datasets/YuGiOhCards/Spell_Cards/Quick-Play_Spell_Cards'
rit_spell_path = 'Y:/Datasets/YuGiOhCards/Spell_Cards/Ritual_Spell_Cards'
# Trap Cards
cont_trap_path = 'Y:/Datasets/YuGiOhCards/Trap_Cards/Continuous_Trap_Cards'
counter_trap_path = 'Y:/Datasets/YuGiOhCards/Trap_Cards/Counter_Trap_Cards'
norm_trap_path = 'Y:/Datasets/YuGiOhCards/Trap_Cards/Normal_Trap_Cards'

csv_file_path = 'Y:/Datasets/train.csv'


fields = (
    'ID', 'Label',
    'Cat', 'Dog',
    'Normal Spell Card', 'Continuous Spell Card', 'Equip Spell Card', 'Quick-Play Spell Card',
    'Field Spell Card', 'Ritual Spell Card',
    'Normal Trap Card', 'Continuous Trap Card', 'Counter Trap Card',
    'Normal Monster Card', 'Effect Monster Card', 'Ritual Monster Card', 'Fusion Monster Card',
    'Synchro Monster Card', 'Xyz Monster Card', 'Pendulum Monster Card', 'Link Monster Card', 'Token Monster Card'
)

with open (csv_file_path, 'w') as f:
    wr = csv.DictWriter(f, fieldnames=fields, lineterminator='\n')
    wr.writeheader()

    for root, dirs, files in os.walk(cat_images_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Cat',
        'Cat':1, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(efct_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Effect Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':1, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(fus_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Fusion Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':1,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(link_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Link Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':1, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(norm_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Normal Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':1, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(pend_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Pendulum Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':1, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(rit_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Ritual Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':1, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(sync_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Synchro Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':1, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(xyz_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Xyz Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':1, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })
    for root, dirs, files in os.walk(tok_mon_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Token Monster Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':1
                        })
    for root, dirs, files in os.walk(cont_spell_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Continuous Spell Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':1, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(equip_spell_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Equip Spell Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':1, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(field_spell_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Field Spell Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':1, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(norm_spell_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Normal Spell Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':1, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(quick_spell_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Quick-Play Spell Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':1,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(rit_spell_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Ritual Spell Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':1,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })
    for root, dirs, files in os.walk(cont_trap_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Continuous Trap Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':1, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(counter_trap_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Counter Trap Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':0, 'Continuous Trap Card':0, 'Counter Trap Card':1,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    for root, dirs, files in os.walk(norm_trap_path):
        for filename in files:
            wr.writerow({
        'ID': filename, 'Label': 'Normal Trap Card',
        'Cat':0, 'Dog':0,
        'Normal Spell Card':0, 'Continuous Spell Card':0, 'Equip Spell Card':0, 'Quick-Play Spell Card':0,
        'Field Spell Card':0, 'Ritual Spell Card':0,
        'Normal Trap Card':1, 'Continuous Trap Card':0, 'Counter Trap Card':0,
        'Normal Monster Card':0, 'Effect Monster Card':0, 'Ritual Monster Card':0, 'Fusion Monster Card':0,
        'Synchro Monster Card':0, 'Xyz Monster Card':0, 'Pendulum Monster Card':0, 'Link Monster Card':0, 'Token Monster Card':0
                        })

    print("Complete")
# Out:
# Complete

# %%
import os

yugi_path = 'Y:/Datasets/YuGiOhCards/Subset/pictures'

for root, dirs, files in os.walk(yugi_path):
    for filename in files:
        if not filename.endswith('.jpg'):
            os.rename(os.path.join(yugi_path,filename), os.path.join(yugi_path,filename)+'.jpg')
